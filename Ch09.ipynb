# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data = np.arange(9)

# %%
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="590.0000156296628">

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
ax1 = fig.add_subplot(2,2,1)

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
fig
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
# Out:
# <img src="data:image/png;base64,..." width="967.7778034151343">

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
 _ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
data = np.random.randn(30).cumsum()

# %%
data
# Out:
# array([ 0.24386869, -0.11619462,  1.42655183, -0.46839715, -0.32428034,
#        -0.19976846, -0.11059325,  1.04411878,  1.69411382,  0.90081488,
#         0.45204029,  0.60625692, -0.87528543, -1.36840437, -1.58704882,
#        -1.59930777, -0.4271437 , -0.95991282, -1.58711991, -0.92092596,
#        -1.09973097, -1.08501939, -0.26587377, -0.09662034,  2.04809206,
#         2.76681535,  4.32382891,  4.80764412,  4.76890785,  3.62881065])

# %%
plt.plot(data, 'k--', label = 'Default')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
plt.plot(data, 'k-', label = 'steps-post', drawstyle='steps-post')

# %%
plt.legend(loc = 'best')
